# %%
# ============================== # 2️⃣ PIE CHART PROPORSI KESELURUHAN # ============================== st.subheader("2️⃣ Proporsi Jawaban Keseluruhan") fig2 = px.pie( values=distribusi.values, names=distribusi.index, title="Proporsi Jawaban Keseluruhan" ) st.plotly_chart(fig2, use_container_width=True)
